# %% [markdown]
# ### Python module/package imports for this chapter

# %%
import sys, os, math, random, functools

import numpy as np

import matplotlib
import matplotlib.pyplot as pp
import matplotlib.animation as anim

# %matplotlib inline

from IPython.display import display, HTML

# %% [markdown]
# ### Code from previous videos (enhanced)

# %%
from turtle import Turtle, Terrarium

# %% [markdown]
# ## Exploiting class inheritance in Python

# %%
def polyspi(t,side,angle):
    if side:
        t.forward(side)
        t.right(angle)
        polyspi(t,side-2,angle)

# %%
with Terrarium(animate=True) as t:
    t1 = Turtle(t,'coral')

    t1.point(1)
    polyspi(t1,100,119)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-3bf7d0424988> in <module>()
#       3
#       4     t1.point(1)
# ----> 5     polyspi(t1,100,119)
#
# C:\Users\Artur_Zahreba\Desktop\ML\Python\Python Programming Efficiently\Ex_Files_Python_Efficiently\Exercise Files\chapter4\04_03\turtle.py in __exit__(self, *args)
#     124         if isinstance(self.axes,animaxes):
#     125             anim = self.axes.animation()
# --> 126             display(HTML(anim.to_html5_video()))
#     127             pp.close()
#
# C:\Users\Artur_Zahreba\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\animation.py in to_html5_video(self)
#    1153                 # We create a writer manually so that we can get the
#    1154                 # appropriate size for the tag
# -> 1155                 Writer = writers[rcParams['animation.writer']]
#    1156                 writer = Writer(codec='h264',
#    1157                                 bitrate=rcParams['animation.bitrate'],
#
# C:\Users\Artur_Zahreba\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\animation.py in __getitem__(self, name)
#     127         self.ensure_not_dirty()
#     128         if not self.avail:
# --> 129             raise RuntimeError("No MovieWriters available!")
#     130         return self.avail[name]
#     131
#
# RuntimeError: No MovieWriters available!

# %%
with Terrarium(animate=True) as t:
    t1 = Turtle(t,'navy')

    t1.point(1)
    polyspi(t1,60,65)
# Out:
# <video width="500.0" height="500.0" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
with Terrarium() as t:
    t1 = Turtle(t)
    
    t1.left(20)
    for i in range(200):
        t1.forward(1)

# %%
class ShakyTurtle(Turtle):
    def forward(self,distance):
        self.right(random.uniform(-10,10))
        super().forward(random.uniform(0.75,1.25)*distance)

# %%
with Terrarium() as t:
    t1 = ShakyTurtle(t)
    
    t1.left(20)
    for i in range(200):
        t1.forward(1)

# %%
with Terrarium() as t:
    t1 = ShakyTurtle(t)
    
    polyspi(t1,100,119)

# %%
class ShakyTurtle(Turtle):
    def __init__(self,t,col='b',shakiness=10):
        super().__init__(t,col)
        self.shakiness = shakiness
    
    def forward(self,distance):
        self.right(random.uniform(-1,1)*self.shakiness)
        super().forward(random.uniform(0.75,1.25)*distance)

# %%
with Terrarium() as t:
    t1 = ShakyTurtle(t,'navy',5)
    t2 = ShakyTurtle(t,'coral',10)
    t3 = ShakyTurtle(t,'seagreen',50)
    
    t1.left(20)
    for i in range(200):
        for ti in [t1,t2,t3]:
            ti.forward(1)

# %%
class PredatorTurtle(ShakyTurtle):
    def follow(self,prey,distance):
        dx, dy = prey.pos[0] - self.pos[0], prey.pos[1] - self.pos[1]
        angle_to_prey = math.atan2(dy,dx) / self.deg - self.angle
        
        self.left(angle_to_prey)
        super().forward(distance)

# %%
with Terrarium(animate=True) as t:
    t1 = ShakyTurtle(t,'navy',20)
    t2 = PredatorTurtle(t,'coral',10)
    
    for i in range(200):
        t1.forward(1)
        t2.follow(t1,0.75)
        
    t1.point(); t2.point()
# Out:
# <video width="500.0" height="500.0" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
def move(turtle,pos):
    turtle.pos = pos
    
Turtle.move = move

# %%
with Terrarium(animate=True) as t:
    t1 = ShakyTurtle(t,'navy',20)
    t2 = PredatorTurtle(t,'coral',10)
    
    t1.move((75,75))
    
    for i in range(200):
        t1.forward(1)
        t2.follow(t1,0.75)
        
    t1.point(); t2.point()
# Out:
# <video width="500.0" height="500.0" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
